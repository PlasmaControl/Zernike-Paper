# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt 
import mpmath
import timeit

sys.path.insert(0, os.path.abspath("."))
sys.path.append(os.path.abspath("./ZERN/"))

from zern.zern_core import Zernike
import numpy as np

sys.path.insert(0, os.path.abspath("."))
sys.path.append(os.path.abspath("./zernike/"))
from zernike import RZern

sys.path.insert(0, os.path.abspath("."))
sys.path.append(os.path.abspath("./zernpy/src/"))
from zernpy import ZernPol

from zernipax.basis import ZernikePolynomial
from zernipax.zernike import *
from zernipax.plotting import plot_comparison
from zernipax.backend import jax

# %%
res = 50
basis = ZernikePolynomial(L=res, M=res, spectral_indexing="ansi", sym="cos")
ms = basis.modes[:,1]
ns = basis.modes[:,0]
r = np.linspace(0, 1, 100)

# %%
def fun_zernipax_clear(ns, ms, r):
    jax.clear_caches()
    return zernike_radial(r, ns, ms, 0)

def fun_zernipax(ns, ms, r):
    return zernike_radial(r, ns, ms, 0)

# %timeit fun_zernipax(ns, ms, r).block_until_ready()
# %timeit fun_zernipax_clear(ns, ms, r).block_until_ready()
all_zernipax = fun_zernipax(ns, ms, r)
# Out:
# 2.08 ms ± 2.79 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 420 ms ± 3.34 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
def fun_zern(ns, ms, r):
    zern = Zernike(0)
    all = []
    for i in range(len(ms)): 
        all.append(zern.R_nm_Jacobi(int(ns[i]), int(ms[i]), r))

    return np.array(all)

all_zern = fun_zern(ns, ms, r).T

# %%
def get_Noll(n, m):
    j = n*(n+1)//2 + abs(m)
    if m >= 0 and (n%4 == 2 or n%4 == 3):
        j += 1
    elif m <= 0 and (n%4 == 0 or n%4 == 1):
        j += 1
    return j

def fun_zernike(ns, ms, r):
    all = []
    cart = RZern(int(max(ns)))
    for i in range(len(ms)):
        id_Noll = get_Noll(ns[i], ms[i]) - 1
        all.append(cart.Rnm(id_Noll, r))

    return np.array(all)

all_zernike = fun_zernike(ns, ms, r).T

# %%
def fun_zernpy(ns, ms, r):
    all = []
    for i in range(len(ms)):
        zp = ZernPol(m=int(ms[i]), n=int(ns[i]))   
        all.append(zp.radial(r))

    return np.array(all)

all_zernpy = fun_zernpy(ns, ms, r).T
# Out:
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=1, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=3, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=5, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=7, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=9, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=11, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=13, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=15, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=17, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=19, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=21, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=23, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=25, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=27, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=29, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=31, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=33, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=35, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=37, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=39, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=41, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=43, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=45, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=47, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=49, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=51, n=51) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=0, n=52) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=2, n=52) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=4, n=52) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=6, n=52) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=8, n=52) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=10, n=52) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=12, n=52) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# /home/ye2698/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:486: UserWarning: ZernPol(m=14, n=52) has actually high radial order, recursive calculations will be slow
#   warnings.warn(warn_mess)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 9
#       5         all.append(zp.radial(r))
#       7     return np.array(all)
# ----> 9 all_zernpy = fun_zernpy(ns, ms, r).T
#
# Cell In[23], line 5, in fun_zernpy(ns, ms, r)
#       3 for i in range(len(ms)):
#       4     zp = ZernPol(m=int(ms[i]), n=int(ns[i]))
# ----> 5     all.append(zp.radial(r))
#       7 return np.array(all)
#
# File ~/ZERNIKE-PAPER/zernpy/src/zernpy/zernikepol.py:489, in ZernPol.radial(self, r, use_exact_eq)
#     487             self.__show_slow_calc_warn = True
#     488         # Returning values using recursive scheme for finding the coefficients for all radial orders (e.g. R^6)
# --> 489         return radial_polynomial_coeffs(self, r)
#     490 else:
#     491     if self.__n > MAX_RADIAL_ORDER_COEFFS:
#
# File ~/ZERNIKE-PAPER/zernpy/src/zernpy/calculations/calc_zernike_pol.py:504, in radial_polynomial_coeffs(zernike_pol, r)
#     502         r_sum = float(n)*np.power(r, n) - float(n-1)*np.power(r, n-2)
#     503     else:
# --> 504         r_sum = (r*(radial_polynomial_coeffs((abs(m-1), n-1), r) + radial_polynomial_coeffs((m+1, n-1), r))
#     505                  - radial_polynomial_coeffs((m, n-2), r))  # general recurrence formula from [1]
#     506 return r_sum
#
# File ~/ZERNIKE-PAPER/zernpy/src/zernpy/calculations/calc_zernike_pol.py:504, in radial_polynomial_coeffs(zernike_pol, r)
#     502         r_sum = float(n)*np.power(r, n) - float(n-1)*np.power(r, n-2)
#     503     else:
# --> 504         r_sum = (r*(radial_polynomial_coeffs((abs(m-1), n-1), r) + radial_polynomial_coeffs((m+1, n-1), r))
#     505                  - radial_polynomial_coeffs((m, n-2), r))  # general recurrence formula from [1]
#     506 return r_sum
#
#     [... skipping similar frames: radial_polynomial_coeffs at line 504 (2 times)]
#
# File ~/ZERNIKE-PAPER/zernpy/src/zernpy/calculations/calc_zernike_pol.py:504, in radial_polynomial_coeffs(zernike_pol, r)
#     502         r_sum = float(n)*np.power(r, n) - float(n-1)*np.power(r, n-2)
#     503     else:
# --> 504         r_sum = (r*(radial_polynomial_coeffs((abs(m-1), n-1), r) + radial_polynomial_coeffs((m+1, n-1), r))
#     505                  - radial_polynomial_coeffs((m, n-2), r))  # general recurrence formula from [1]
#     506 return r_sum
#
# File ~/ZERNIKE-PAPER/zernpy/src/zernpy/calculations/calc_zernike_pol.py:505, in radial_polynomial_coeffs(zernike_pol, r)
#     502         r_sum = float(n)*np.power(r, n) - float(n-1)*np.power(r, n-2)
#     503     else:
#     504         r_sum = (r*(radial_polynomial_coeffs((abs(m-1), n-1), r) + radial_polynomial_coeffs((m+1, n-1), r))
# --> 505                  - radial_polynomial_coeffs((m, n-2), r))  # general recurrence formula from [1]
#     506 return r_sum
#
# File ~/ZERNIKE-PAPER/zernpy/src/zernpy/calculations/calc_zernike_pol.py:504, in radial_polynomial_coeffs(zernike_pol, r)
#     502         r_sum = float(n)*np.power(r, n) - float(n-1)*np.power(r, n-2)
#     503     else:
# --> 504         r_sum = (r*(radial_polynomial_coeffs((abs(m-1), n-1), r) + radial_polynomial_coeffs((m+1, n-1), r))
#     505                  - radial_polynomial_coeffs((m, n-2), r))  # general recurrence formula from [1]
#     506 return r_sum
#
# File ~/ZERNIKE-PAPER/zernpy/src/zernpy/calculations/calc_zernike_pol.py:504, in radial_polynomial_coeffs(zernike_pol, r)
#     502         r_sum = float(n)*np.power(r, n) - float(n-1)*np.power(r, n-2)
#     503     else:
# --> 504         r_sum = (r*(radial_polynomial_coeffs((abs(m-1), n-1), r) + radial_polynomial_coeffs((m+1, n-1), r))
#     505                  - radial_polynomial_coeffs((m, n-2), r))  # general recurrence formula from [1]
#     506 return r_sum
#
#     [... skipping similar frames: radial_polynomial_coeffs at line 504 (2 times)]
#
# File ~/ZERNIKE-PAPER/zernpy/src/zernpy/calculations/calc_zernike_pol.py:504, in radial_polynomial_coeffs(zernike_pol, r)
#     502         r_sum = float(n)*np.power(r, n) - float(n-1)*np.power(r, n-2)
#     503     else:
# --> 504         r_sum = (r*(radial_polynomial_coeffs((abs(m-1), n-1), r) + radial_polynomial_coeffs((m+1, n-1), r))
#     505                  - radial_polynomial_coeffs((m, n-2), r))  # general recurrence formula from [1]
#     506 return r_sum
#
# File ~/ZERNIKE-PAPER/zernpy/src/zernpy/calculations/calc_zernike_pol.py:492, in radial_polynomial_coeffs(zernike_pol, r)
#     490     for key, value in pols_coeffs.items():
#     491         if abs(value) > 0:
# --> 492             r_sum += value*np.power(r, key)
#     493 # Special case - for really high orders
#     494 else:
#     495     # Recurrence equations - stable way to refer previously stably calculated values
#     496     # Simple check that values stably calculated - radial polynomial values shouldn't exceed 1.0
#     497     if abs(m) == n:  # derivative from the simplified recurrence formula from [3]
#
# KeyboardInterrupt:

# %%
# Exact computation
mpmath.mp.dps = 100
def fun_exact(ns, ms, r):
    c = zernike_radial_coeffs(ns, ms, exact=True)
    zt0 = np.array([np.asarray(mpmath.polyval(list(ci), r), dtype=float) for ci in c]).T
    return zt0

exact = fun_exact(ns, ms, r)

# %%
plot_comparison(
    exact, 
    (all_zernipax, all_zern),
    basis, 
    dx=0, 
    type="absolute", 
    names=("Zernipax:", "Zern:"), 
    print_error=True
)

# %%
plot_comparison(
    exact, 
    (all_zernipax, all_zern, all_zernike, all_zernpy),
    basis, 
    dx=0, 
    type="absolute", 
    names=("Zernipax:", "Zern:", "Zernike:", "Zernpy:"), 
    print_error=True
)
# plt.savefig("comparison_all.png", dpi=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 plot_comparison(
#       2     exact,
#       3     (all_zernipax, all_zern, all_zernike, all_zernpy),
#       4     basis,
#       5     dx=0,
#       6     type="absolute",
#       7     names=("Zernipax:", "Zern:", "Zernike:", "Zernpy:"),
#       8     print_error=True
#       9 )
#      10 # plt.savefig("comparison_all.png", dpi=1000)
#
# File ~/ZERNIKE-PAPER/zernipax/plotting.py:304, in plot_comparison(exact, methods, basis, dx, type, names, print_error)
#     302 title = description + "$\\max_{x \\in (0,1)} |" + Zmn + "-" + Zmn_p
#     303 if type == "absolute":
# --> 304     c = np.max(abs(methods[i] - exact), axis=0) / np.mean(abs(exact))
#     305     title = title + "|$"
#     306 else:
#
# ValueError: operands could not be broadcast together with shapes (100,676) (100,2601)

# %%
print("Time for ZERN:")
# %timeit fun_zern(ns, ms, r);
print("Time for ZERNIKE:")
# %timeit fun_zernike(ns, ms, r);
# print("Time for ZERNPY:")
# %timeit fun_zernpy(ns, ms, r);
print("Time for ZERNIPAX:")
# %timeit fun_zernipax(ns, ms, r).block_until_ready();
# Out:
# Time for ZERN:
# 66.8 ms ± 3.46 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Time for ZERNIKE:
# 85.3 ms ± 2.02 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# Time for ZERNIPAX:
# 1.98 ms ± 20.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
r = np.linspace(0, 1, 100)
times = []
num_exec = 100
range_res = np.arange(10, 51, 5)
from tqdm import tqdm

for res in tqdm(range_res):
    basis = ZernikePolynomial(L=res, M=res, spectral_indexing="ansi", sym="cos")
    ms = basis.modes[:,1]
    ns = basis.modes[:,0]
    _ = fun_zernipax(ns, ms, r) # run to compile it once

    t1 = timeit.timeit(lambda: fun_zern(ns, ms, r), number=num_exec)
    t2 = timeit.timeit(lambda: fun_zernike(ns, ms, r), number=num_exec)
    t3 = timeit.timeit(lambda: fun_zernipax(ns, ms, r).block_until_ready(), number=num_exec)
    t4 = timeit.timeit(lambda: fun_zernipax_clear(ns, ms, r).block_until_ready(), number=num_exec)

    times.append([t1, t2, t3, t4])
times = np.array(times)*1000/num_exec
# Out:
# 100%|██████████| 19/19 [12:04<00:00, 38.13s/it]

# %%
plt.plot(range_res, times[:,0], label="ZERN")
plt.plot(range_res, times[:,1], label="ZERNIKE")
plt.plot(range_res, times[:,2], label="ZERNIPAX")
# plt.plot(range_res, 0.001*range_res**3, label="order")
plt.xlabel("Resolution")
plt.ylabel("Time (ms)")
plt.title("Time Comparison of Computation of Radial Zernike Polynomials")
plt.grid()
plt.legend()
# plt.savefig("time_comparison.png", dpi=1000)

# %%
plt.plot(range_res, times[:,2], label="ZERNIPAX")
# plt.plot(range_res, 0.00003*range_res**3, label="order")
plt.xlabel("Resolution")
plt.ylabel("Time (ms)")
plt.title("Computation Time of Radial Zernike Polynomials in ZERNIPAX")
plt.grid()
plt.legend()
# plt.savefig("time_zernipax.png", dpi=1000)
